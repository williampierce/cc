# %%
# %matplotlib inline

# %%
# %run ~/git/cc/tools/dsp/notebooks/notebook_setup_dsp.py

# %%
import plotSeries

# %%
cd /Users/billpierce/audio/dataset1/
# Out:
# /Users/billpierce/audio/dataset1

# %%
plt.rcParams['figure.figsize'] = (24.0, 16.0)

# %%
plotSeries.plot_series("Samples_001", number_samples=5, upper_frequency=4000)
