# %%
# %matplotlib inline

# %%
# %run ~/git/cc/tools/dsp/notebooks/notebook_setup_dsp.py

# %%
import plotSeries

# %%
cd /Users/billpierce/audio/dataset2/
# Out:
# /Users/billpierce/audio/dataset2

# %%
plt.rcParams['figure.figsize'] = (24.0, 16.0)

# %%
plotSeries.plot_series("Samples_020", number_samples=20, upper_frequency=150)

# %%
plotSeries.plot_series("Samples_021", number_samples=20, upper_frequency=150)

# %%
plotSeries.plot_series("Samples_022", number_samples=20, upper_frequency=150)

# %%
plotSeries.plot_series("Samples_023", number_samples=20, upper_frequency=150)

# %%
plotSeries.plot_series("Samples_024", number_samples=20, upper_frequency=150)

# %%
plotSeries.plot_series("Samples_025", number_samples=20, upper_frequency=150)

# %%
plotSeries.plot_series("Samples_026", number_samples=20, upper_frequency=150)

# %%
plotSeries.plot_series("Samples_027", number_samples=20, upper_frequency=150)

# %%
plotSeries.plot_series("Samples_028", number_samples=20, upper_frequency=150)

# %%
plotSeries.plot_series("Samples_029", number_samples=20, upper_frequency=150)
